# %%
import pandas as pd 
import plotly.express as px
import hvplot.pandas 
from sklearn.cluster import KMeans

file_path = "dataexport.csv"
df = pd.read_csv(file_path)

# %%
df.hvplot.scatter(x="degrees_from_mean", y="type")
# Out:
# :Scatter   [degrees_from_mean]   (type)

# %%
df.hvplot.scatter(x="max_temp", y="type")
# Out:
# :Scatter   [max_temp]   (type)

# %%
df.hvplot.scatter(x="min_temp", y="type")
# Out:
# :Scatter   [min_temp]   (type)

# %%
df.hvplot.scatter(x="date_str", y="type")
# Out:
# :Scatter   [date_str]   (type)

# %%
fig_1 = px.scatter_3d(df, x="max_temp", y="min_temp", z="degrees_from_mean", color="type", symbol="type")
fig_1.show()
# Out:
# <div>                            <div id="6c1b7e08-66f5-44ee-a283-8b977738cf33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c1b7e08-66f5-44ee-a283-8b977738cf33")) {                    Plotly.newPlot(                        "6c1b7e08-66f5-44ee-a283-8b977738cf33",                        [{"hovertemplate":"type=Weak Hot<br>max_temp=%{x}<br>min_temp=%{y}<br>degrees_from_mean=%{z}<extra></extra>","legendgroup":"Weak Hot","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Weak Hot","scene":"scene","showlegend":true,"x":[33.3,28.3,29.4,33.3,26.1,32.2,33.9,31.7,33.3,25.0,25.6,25.0,24.4,32.2,35.6,35.6,25.0,33.9,27.8,29.4,30.0,31.1,26.7,27.2,31.7,33.3,31.7,31.7,31.7,31.1,29.4,25.6,40.0,36.1,37.8,37.2,21.7,37.8,27.8,23.3,26.1,26.1,41.
# ...
